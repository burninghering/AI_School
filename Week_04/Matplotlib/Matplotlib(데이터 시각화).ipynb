# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.linspace(0,10,100) #0부터10까지 100개의 점을 만들어라

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x,np.sin(x))

# %%
plt.plot(x,np.cos(x)) #x축은 그대로 전달, y값은 cos값 전달

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %%
fig=plt.figure()

plt.plot(x,np.sin(x),'-')
plt.plot(x,np.cos(x),'--')

fig.savefig('my_figure.png')

# %%
from IPython.display import Image

# %%
Image('my_figure.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
plt.figure()

# %%
plt.subplot(2,1,1)
#그림 2개를 그릴건데, 1줄로 그릴거고 1번째다
plt.plot(x,np.sin(x))
#그림판 하나 안에 두 개의 이미지를 넣으려면.. 한 개의 이미지를 subplot이라고 한다

plt.subplot(2,1,2)
plt.plot(x,np.cos(x))

# %%
plt.plot(x,np.sin(x-0),color='blue')
plt.plot(x,np.sin(x-1),color='g')
plt.plot(x,np.sin(x-2),color='0') #0~1까지의 음영을 나타냄
plt.plot(x,np.sin(x-3),color='#FFDD44')
plt.plot(x,np.sin(x-4),color=(1.0,0.2,0.3)) #R,G,B 0~1사이의 값
plt.plot(x,np.sin(x-5),color='chartreuse')

# %%
plt.plot(x,x+0,linestyle='solid') #매끈한 선은 solid
plt.plot(x,x+1,linestyle='dashed')
plt.plot(x,x+2,linestyle='dashdot')
plt.plot(x,x+3,linestyle='dotted')

plt.plot(x,x+4,linestyle='-') 
plt.plot(x,x+5,linestyle='--')
plt.plot(x,x+6,linestyle='-.')
plt.plot(x,x+7,linestyle=':')

# %%
plt.plot(x,x+0,'-g')
plt.plot(x,x+1,'--c')
plt.plot(x,x+2,'-.k')
plt.plot(x,x+3,':r')

# %%
plt.plot(x,np.sin(x))
plt.xlim(10,0) #시작 위치 10부터 0 (그래프를 뒤집어서 보는 효과)
plt.ylim(1.2,-1.2)
# Out:
# (1.2, -1.2)

# %%
plt.plot(x,np.sin(x))
plt.axis([-0.5,11,-1.5,1.5])
# Out:
# (-0.5, 11.0, -1.5, 1.5)

# %%
plt.plot(x,np.sin(x))
plt.axis('tight')
# Out:
# (-0.5, 10.5, -1.0993384025373631, 1.0996461858110391)

# %%
plt.plot(x,np.sin(x))
plt.axis('equal') #양 쪽 기준이 똑같게
# Out:
# (-0.5, 10.5, -1.0993384025373631, 1.0996461858110391)

# %%
plt.plot(x,np.sin(x),'-g',label='sin(x)') #label로 텍스트 출력

# %%
plt.plot(x,np.sin(x))
plt.title('A Sine Curve')
plt.xlabel('x')
plt.ylabel('sin(x)')
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
plt.plot(x,np.sin(x),'-g',label='sin(x)')
plt.plot(x,np.cos(x),':b',label='cos(x)')
plt.axis('equal')

plt.legend() #설명이 나온다

# %%
x=np.linspace(0,10,30) #0부터 10까지 30개만
plt.plot(x,np.sin(x),'o',color='black') #점으로 표시하기 (=산점도)

# %%
rng=np.random.RandomState(0)
for marker in ['o',',',',','x','+','v','^','<','>','s','d']: #하나씩 마커에 대입되면서 마크 기입이 됨
    plt.plot(rng.rand(5), rng.rand(5),marker, #5안에서 값이 잡히게 하자
             label='marker={0}'.format(marker)) 
    
    plt.legend()

# %% [markdown]
# numpy.random.RandomState(123)
#
# :numpy.random.RandomState는 class명으로
#
# 랜덤넘버 생성기인 랜덤함수들을 포함하는 클래스라고 할 수 있다.
#
# RandomState는 다양한 확률분포측면에 수 많은 랜덤넘버 생성기들을 가지고 있다.
#
# ex) numpy.random.uniform(균등분포에서 변수 추출),
#
#        numpy.random.nomal(정규분포에서 변수 추출), 등
#
#   각 방법들은 size를 argument로 취하는데 기본값은 None이다. 만약 size가 None이라면, 하나의 값이 생성되고 반환된다. 만약 size가 정수라면, 1-D 행렬이 랜덤변수들로 채워져 반환된다. 만약 size가 tuple이라면 행렬이 그 형태에 맞추어 랜덤변수들로 채워져 반환된다.
#
#
# rng = numpy.random.RandomState(123)과 같이 클래스 변수 rng를 선언 할 수 있습니다. 이때 123은 일종의 번호로 randomstate 변수를 생성할 때 번호를 지정해서 넣어주지 않으면, 여러개의 randomstate 변수를 사용할 때 모두 같은 random한 값을 출력하게됩니다. 따라서 선언시에 각 변수 마다 다른 값을 넣음으로서 하나의 코드상에서 다른 랜덤한 값을 출력할 수 있게됩니다.

# %%
y=np.sin(x)
plt.plot(x,y,'-ok') #점으로 표현하면서 'k' 블랙으로 표현하기

# %%
plt.plot(x,y,'-p',color='gray',markersize=15,markerfacecolor='white',markeredgecolor='gray',markeredgewidth=2) #-를 붙이면 선이 이어진다

# %%
plt.scatter(x,y)

# %%
rng=np.random.RandomState(0) #난수를 섞는데, 시드값이 0이라 똑같이 섞인다
x=rng.randn(100) #x에 랜덤으로 100개의 값이 찍힌다
y=rng.randn(100) 

color=rng.rand(100)
sizes=1000*rng.rand(100)

plt.scatter(x,y, c=color, s=sizes, alpha=0.3,cmap='viridis') #x,y는 별다른 지정이 없으면 0~2

# %%
from sklearn.datasets import load_iris
iris=load_iris()
features=iris.data.T

# %%
features #갑자기 배열로 나오는 이유는 Numpy 배열로 저장이 되어있기 때문
features.shape
# Out:
# (4, 150)

# %%
plt.scatter(features[0],features[1],alpha=0.2,s=features[3]*100,cmap='viridis',
           c=iris.target)
#(x축의 첫번째 피쳐,두번째 피쳐) alpha는 너무 겹쳐서 안보일까봐

plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %%
#errorbar
x=np.linspace(0,10,50)
dy=0.8

y=np.sin(x) + dy * np.random.randn(50)

plt.errorbar(x,y,yerr=dy,fmt='.k') #yerr은 세로축으로 에러를 표시하기, fmt는 점으로 표시하기
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x,y,yerr=dy,fmt='o',color='black',
            ecolor='lightgray',elinewidth=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # Style 지정하기

# %%
plt.style.use('classic')
plt.errorbar(x,y,yerr=dy,fmt='o',color='black',
            ecolor='lightgray',elinewidth=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.style.use('seaborn-whitegrid')
plt.errorbar(x,y,yerr=dy,fmt='o',color='black',
            ecolor='lightgray',elinewidth=3)
# Out:
# <ErrorbarContainer object of 3 artists>
